# %% [markdown]
# ##PRCP-1004-Fifa20

# %% [markdown]
# # **Problem Statement**
#
# Task 1:-Prepare a complete data analysis report on the given data.
#
# Task 2:- Explore football skills and cluster football players based on their attributes.
#
# Task3:- Explore the data and attempt all the below asked questions in a
# step by step manner:
#
# ● Prepare a rank ordered list of top 10 countries with most players. Which
# countries are producing the most footballers that play at this level?
#
# ● Plot the distribution of overall rating vs. age of players. Interpret what is theage after which a player stops improving?
#
# ● Which type of offensive players tends to get paid the most: the striker, the
# right-winger, or the left-winger?

# %% [markdown]
# # **Attributes:**
#
# ● Name: Name of the player.
#
# ● Age: Age of the player.
#
# ● Height: Height of the player in inches (transformed to centimeters in
# preprocessing).
#
# ● Overall: General performance quality and value of the player representing
# the key positional skills and international reputation rated between 1-99.
# Overall attribute is used only in preprocessing and discussion stages because
# using it in modelling could lead to domination by this feature. The aim of the
# project is not basically sort and categorize the players using their overall
# talent and international reputation, but to cluster them based on using their
# whole skillset.
#
# ● Potential: Maximum Overall rating expected to be reached by a player in the
# top of his career rated between 1-99.
#
# ● PreferredFoot: Right or Left. Label encoder is applied as 0 for left and 1 for
# right.
#
# ● WeakFoot: Represents how well a player uses his weak foot (e.g. left for
# righties) rated between 1 to 5.
#
# ● WorkRate: Degree of the effort the player puts in terms of attack and
# defense rated as low, medium and high. This feature is divided into two new
# features as AttackWorkRate and DefenseWorkRate. Besides, label encoder
# is applied as 0 for low, 0.5 for medium and 1 for high.
#
# ● Position: Position of the players on the pitch which determines their roles
# and responsibilities in the team. Forward positions in the football and FIFA
# 19 can be grouped as striker (ST: center striker, RS: right striker, LS: left
# striker), forward (CF: center forward, RF: right forward, LF: left forward)
# and winger (RW: right winger, LW: left winger). The word, forward, is used
# both as a general term and a special position. Strikers are positioned in front
# of forwards and wingers and very closed to the opposing goal. Their main
# responsibilities are attacking and scoring goals, that’s why their ball control,
# shooting and finishing skills are expected to be well. Center forwards are
# positioned right behind the strikers. They are expected to receive balls from
# the others and score assists to the others or goals. In addition to the skills
# expected from strikers, they have to be good at passing. Right forwards and
# left forwards are positioned at the right and left of the center forwards with
# the same expectations. Wingers are positioned near the touchlines to create
# chances for strikers and forwards from the right and left side of the field by
# breakthrough and crosses and to score goals. They are expected to be good
# at dribbling, acceleration, passing and crossing. Positions are used only in
# preprocessing and discussion stages.
#
# ● ST: Positional skill. Player’s general ability when playing in ST
# position rated between 1-99.
#
# ● RS: Positional skill. Player’s general ability when playing in in RS
# position rated between 1-99.
#
# ● LS: Positional skill. Player’s general ability when playing in in LS
# position rated between 1-99.
#
# ● CF: Positional skill. Player’s general ability when playing in in CF
# position rated between 1-99.
#
# ● RF: Positional skill. Player’s general ability when playing in in RF
# position rated between 1-99.
#
# ● LF: Positional skill. Player’s general ability when playing in in LF
# position rated between 1-99.
#
# ● RW: Positional skill. Player’s general ability when playing in in RW
# position rated between 1-99.
#
# ● LW: Positional skill. Player’s general ability when playing in in LW
# position rated between 1-99.
#
# ● Crossing: Crossing skill of the player rated between 1-99. Cross is a
# long-range pass from wings to center.
#
# ● Finishing: Finishing skill of the player rated between 1-99. Finishing in
# football refers to finish an attack by scoring a goal.
#
# ● HeadingAccuracy: Player’s accuracy to pass or shoot by using his head
# rated between 1-99.
#
# ● ShortPassing: Player’s accuracy for short passes rated between 1-99.
#
# ● LongPassing: Player’s accuracy for long passes rated between 1-99.
#
# ● Dribbling: Dribbling skill of the player rated between 1-99. Dribbling is
# carrying the ball without losing while moving in one particular
# direction.
#
# ● SprintSpeed: Speed rate of the player rated between 1-99.
#
# ● Acceleration: Shows how fast a player can reach his maximum sprint
# speed rated between 1-99.
#
# ● FKAccuracy: Player’s accuracy to score free kick goals rated between
# 1-99.
#
# ● BallControl: Player’s ability to control the ball rated between 1-99.
#
# ● Balance: Player’s ability to remain steady while running, carrying and
# controlling the ball rated between 1-99.
#
# ● ShotPower: Player’s strength level of shooting the ball rated between 1-
# 99.
#
# ● Jumping: Player’s jumping skill rated between 1-99.
#
# ● Penalties: Player’s accuracy to score goals from penalty rated between
# 1-99.
#
# ● Strength: Physical strength of the player rated between 1-99.
#
# ● Agility: Gracefulness and quickness of the player while controlling the
# ball rated between 1-99.
#
# ● Reactions: Acting speed of the player to what happens in his
# environment rated between 1-99.
#
# ● Aggression: Aggression level of the player while pushing, pulling and
# tackling rated between 1-99.
#
# ● Positioning: Player’s ability to place himself in the right position to
# receive the ball or score goals rated between 1-99.
#
# ● Vision: Player’s mental awareness about the other players in the team
# for passing rated between 1-99.
#
# ● Volleys: Player’s ability to perform volleys rated between 1-99.
#
# ● LongShots: Player’s accuracy of shoots from long distances rated
# between 1-99.
#
# ● Stamina: Player’s ability to sustain his stamina level during the match
# rated between 1-99. Players with lower stamina get tired fast.
#
# ● Composure: Player’s ability to control his calmness and frustration
# during the match rated between 1-99.
#
# ● Curve: Player’s ability to curve the ball while passing or shooting rated
# between 1-99.
#
# ● Interceptions: Player’s ability to intercept the ball while opposite
# team’s players are passing rated between 1-99. It is a defensive skill.
#
# ● StandingTackle: Player’s ability to perform tackle (take the ball from
# the opposite player) while standing rated between 1-99. It is a defensive
# skill.
#
# ● SlidingTackle: Player’s ability to perform tackle by sliding rated
# between 1-99. It is a defensive skill.
#
# ● Marking: Player’s ability to apply strategies to prevent opposing team
# from taking the ball rated between 1-99. It is a defensive skill.

# %% [markdown]
# # Library Import

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns',100)

# %% [markdown]
# # Data Import

# %%
df = pd.read_csv(r"/content/players_20.csv")

# %% [markdown]
# ## Task-1

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.columns.to_list()
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
df.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 104 columns):
#  #    Column                      Non-Null Count  Dtype
# ---   ------                      --------------  -----
#  0    sofifa_id                   18278 non-null  int64
#  1    player_url                  18278 non-null  object
#  2    short_name                  18278 non-null  object
#  3    long_name                   18278 non-null  object
#  4    age                         18278 non-null  int64
#  5    dob                         18278 non-null  object
#  6    height_cm                   18278 non-null  int64
#  7    weight_kg                   18278 non-null  int64
#  8    nationality                 18278 non-null  object
#  9    club                        18278 non-null  object
#  10   overall                     18278 non-null  int64
#  11   potential                   18278 non-null  int64
#  12   value_eur                   18278 non-null  int64
# ...

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
cat_cols = df.select_dtypes(include="O").columns
print(f'Total Categorical Columns:{len(cat_cols)}')
print(cat_cols)
# Out:
# Total Categorical Columns:43
# Index(['player_url', 'short_name', 'long_name', 'dob', 'nationality', 'club',
#        'player_positions', 'preferred_foot', 'work_rate', 'body_type',
#        'real_face', 'player_tags', 'team_position', 'loaned_from', 'joined',
#        'nation_position', 'player_traits', 'ls', 'st', 'rs', 'lw', 'lf', 'cf',
#        'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb',
#        'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include=["int64","float64"]).columns
print(f'Total Numerical Columns:{len(num_cols)}')
print(num_cols)
# Out:
# Total Numerical Columns:61
# Index(['sofifa_id', 'age', 'height_cm', 'weight_kg', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'international_reputation', 'weak_foot',
#        'skill_moves', 'release_clause_eur', 'team_jersey_number',
#        'contract_valid_until', 'nation_jersey_number', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'gk_diving',
#        'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
# ...

# %%
df.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
for col in df.columns:
    null_df = df[col].isnull().sum()
    print(f'{col}: {null_df}')
# Out:
# sofifa_id: 0
# player_url: 0
# short_name: 0
# long_name: 0
# age: 0
# dob: 0
# height_cm: 0
# weight_kg: 0
# nationality: 0
# club: 0
# overall: 0
# potential: 0
# value_eur: 0
# wage_eur: 0
# player_positions: 0
# preferred_foot: 0
# international_reputation: 0
# weak_foot: 0
# skill_moves: 0
# work_rate: 0
# body_type: 0
# real_face: 0
# release_clause_eur: 1298
# player_tags: 16779
# team_position: 240
# team_jersey_number: 240
# loaned_from: 17230
# joined: 1288
# contract_valid_until: 240
# nation_position: 17152
# nation_jersey_number: 17152
# pace: 2036
# shooting: 2036
# passing: 2036
# dribbling: 2036
# defending: 2036
# physic: 2036
# gk_diving: 16242
# gk_handling: 16242
# gk_kicking: 16242
# gk_reflexes: 16242
# gk_speed: 16242
# gk_positioning: 16242
# player_traits: 10712
# attacking_crossing: 0
# attacking_finishing: 0
# attacking_heading_accuracy: 0
# attacking_short_passing: 0
# attacking_volleys: 0
# skill_dribbling: 0
# skill_curve: 0
# skill_fk_accuracy: 0
# ...

# %%
df['lcm'].mode()[0]
# Out:
# '58+2'

# %%
a = ['63+2','64+1','55+4','45+5']
for i in a:
    val = i.split('+')
    x = int(val[0])
    y = int(val[1])
    res = x+y
    print(res)
# Out:
# 65
# 65
# 59
# 50

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Replace null values
# median for numerical columns
# mode for categorical columns
for cols in df.columns:
    if df[cols].dtype in num_cols:
        median_val = df[cols].median()
        df[cols].fillna(median_val,inplace=True)
    else:
        mode_val = df[cols].mode()[0]
        df[cols].fillna(mode_val,inplace=True)

# %%
for col in df.columns:
    null_df = df[col].isnull().sum()
    print(f'{col}: {null_df}')
# Out:
# sofifa_id: 0
# player_url: 0
# short_name: 0
# long_name: 0
# age: 0
# dob: 0
# height_cm: 0
# weight_kg: 0
# nationality: 0
# club: 0
# overall: 0
# potential: 0
# value_eur: 0
# wage_eur: 0
# player_positions: 0
# preferred_foot: 0
# international_reputation: 0
# weak_foot: 0
# skill_moves: 0
# work_rate: 0
# body_type: 0
# real_face: 0
# release_clause_eur: 0
# player_tags: 0
# team_position: 0
# team_jersey_number: 0
# loaned_from: 0
# joined: 0
# contract_valid_until: 0
# nation_position: 0
# nation_jersey_number: 0
# pace: 0
# shooting: 0
# passing: 0
# dribbling: 0
# defending: 0
# physic: 0
# gk_diving: 0
# gk_handling: 0
# gk_kicking: 0
# gk_reflexes: 0
# gk_speed: 0
# gk_positioning: 0
# player_traits: 0
# attacking_crossing: 0
# attacking_finishing: 0
# attacking_heading_accuracy: 0
# attacking_short_passing: 0
# attacking_volleys: 0
# skill_dribbling: 0
# skill_curve: 0
# skill_fk_accuracy: 0
# skill_long_passing: 0
# skill_ball_control: 0
# movement_acceleration: 0
# ...

# %%
cols_to_fetch = ['ls', 'st', 'rs', 'lw', 'lf', 'cf','rf', 'rw',
                 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb',
                 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']

# %%
def fetch(col):
    val_1 = df[col].str.split('+').str.get(0).astype('int64')
    val_2 = df[col].str.split('+').str.get(1).astype('int64')
    result = val_1 + val_2
    return result
for col in cols_to_fetch:
    df[col] = fetch(col)
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 104 columns):
#  #    Column                      Dtype
# ---   ------                      -----
#  0    sofifa_id                   int64
#  1    player_url                  object
#  2    short_name                  object
#  3    long_name                   object
#  4    age                         int64
#  5    dob                         object
#  6    height_cm                   int64
#  7    weight_kg                   int64
#  8    nationality                 object
#  9    club                        object
#  10   overall                     int64
#  11   potential                   int64
#  12   value_eur                   int64
#  13   wage_eur                    int64
#  14   player_positions            object
#  15   preferred_foot              object
#  16   international_reputation    int64
#  17   weak_foot                   int64
# ...

# %%
cols_to_remove = ['sofifa_id','player_url','long_name','dob','player_positions','body_type','real_face',
                 'player_tags','team_jersey_number','loaned_from','joined','contract_valid_until',
                  'nation_position','nation_jersey_number','player_traits']

# %%
df.drop(cols_to_remove,axis=1,inplace=True)

# %%
df.shape
# Out:
# (18278, 89)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   short_name                  18278 non-null  object
#  1   age                         18278 non-null  int64
#  2   height_cm                   18278 non-null  int64
#  3   weight_kg                   18278 non-null  int64
#  4   nationality                 18278 non-null  object
#  5   club                        18278 non-null  object
#  6   overall                     18278 non-null  int64
#  7   potential                   18278 non-null  int64
#  8   value_eur                   18278 non-null  int64
#  9   wage_eur                    18278 non-null  int64
#  10  preferred_foot              18278 non-null  object
#  11  international_reputation    18278 non-null  int64
#  12  weak_foot                   18278 non-null  int64
# ...

# %% [markdown]
# ## Task-3
#  Explore the data and attempt all the below asked questions in a step by step manner:

# %% [markdown]
# i)Prepare a rank ordered list of top 10 countries with most players. Which
# countries are producing the most footballers that play at this level?

# %%
top_n = df['nationality'].value_counts()[:10]
top_n
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,7))
sns.barplot(x=top_n.index,y=top_n)
plt.tight_layout()

# %% [markdown]
# These are the top 10 countries and hereby European countries such as England, Germany, Spain, France and Italy are
# producing the most players to play at this level.

# %% [markdown]
# ii) Plot the distribution of overall rating vs. age of players. Interpret what is the age after which a player stops improving?**

# %%
plt.figure(figsize=(10, 7))
sns.regplot(data=df, x='age', y='overall', scatter=True, lowess=True, line_kws={'color': 'red'})
plt.title('Overall Rating vs Age of Players')
plt.xlabel('Age')
plt.ylabel('Overall Rating')
plt.show()

# %%
age_rating = df.groupby('age')['overall'].mean()
print(age_rating)
# Out:
# age
# 16    56.416667
# 17    55.786026
# 18    57.273438
# 19    59.507418
# 20    61.222133
# 21    63.262545
# 22    64.609959
# 23    66.038292
# 24    66.977623
# 25    67.904473
# 26    68.400787
# 27    69.013595
# 28    69.216390
# 29    69.308308
# 30    69.420159
# 31    69.938042
# 32    69.941374
# 33    69.488421
# 34    69.591362
# 35    69.961290
# 36    68.145038
# 37    67.814815
# 38    69.452381
# 39    67.250000
# 40    66.076923
# 41    74.500000
# 42    63.500000
# Name: overall, dtype: float64

# %% [markdown]
# Age of Players have been distributed between 16 to 42. Players stops improving after they attains the age of 27.

# %% [markdown]
# iii) Which type of offensive players tends to get paid the most: the striker, the right-winger, or the left-winger?

# %%
plt.figure(figsize=(10,7))
sns.barplot(data=df,x='team_position',y='value_eur')
plt.tight_layout()

# %%
plt.figure(figsize=(10,7))
sns.pointplot(data=df,x='team_position',y='value_eur')
plt.tight_layout()

# %% [markdown]
# Center Forward CF tends to get paid the most than other offensive players

# %% [markdown]
# ## Data Analysis

# %%
df['preferred_foot'].value_counts(normalize=True)
# Out:
# preferred_foot
# Right    0.76376
# Left     0.23624
# Name: proportion, dtype: float64

# %%
sns.countplot(df,x='preferred_foot')
# Out:
# <Axes: xlabel='preferred_foot', ylabel='count'>

# %%
# Historical Comparision
"""
compare_df = pd.concat([df.loc[df['short_name']=="L. Messi"],
             df.loc[df['short_name']=="Cristiano Ronaldo"]])
"""
compare_df = df.iloc[:2]
compare_df
# Out:
#           short_name  age  height_cm  weight_kg nationality          club  \
# 0           L. Messi   32        170         72   Argentina  FC Barcelona
# 1  Cristiano Ronaldo   34        187         83    Portugal      Juventus
#
#    overall  potential  value_eur  wage_eur preferred_foot  \
# 0       94         94   95500000    565000           Left
# 1       93         93   58500000    405000          Right
#
#    international_reputation  weak_foot  skill_moves   work_rate  \
# 0                         5          4            4  Medium/Low
# 1                         5          4            5    High/Low
#
#    release_clause_eur team_position  pace  shooting  passing  dribbling  \
# 0         195800000.0            RW  87.0      92.0     92.0       96.0
# 1          96500000.0            LW  90.0      93.0     82.0       89.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0       64.0         62.0        60.0         64.0
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(5,1,1)
sns.barplot(data=compare_df,x=compare_df['short_name'],y=compare_df['pace'])
plt.title("Comparison based on Players Pace")

plt.subplot(5,1,2)
sns.barplot(data=compare_df,x=compare_df['short_name'],y=compare_df['shooting'])
plt.title("Comparison based on Players Shooting Skill")

plt.subplot(5,1,3)
sns.barplot(data=compare_df,x=compare_df['short_name'],y=compare_df['passing'])
plt.title("Comparison based on Players Passing Skill")

plt.subplot(5,1,4)
sns.barplot(data=compare_df,x=compare_df['short_name'],y=compare_df['dribbling'])
plt.title("Comparison based on Players Dribbling Skill")

plt.subplot(5,1,5)
sns.barplot(data=compare_df,x=compare_df['short_name'],y=compare_df['defending'])
plt.title("Comparison based on Players Defending Skill")

plt.tight_layout()

# %%
### Important playing 11 positions
#[GK, LB, CB, CB, RB, CM, CM, CAM, LW, RW, ST]
# GK, 2 CBs, LB, RB, 2 CDMs, CAM, LM, RM, ST

# %%
df['nationality'].nunique()
# Out:
# 162

# %%
european_countries = [
    'England', 'Germany', 'France', 'Spain', 'Italy', 'Portugal', 'Netherlands', 'Belgium',
    'Switzerland', 'Austria', 'Croatia', 'Denmark', 'Sweden', 'Norway', 'Finland', 'Iceland',
    'Poland', 'Czech Republic', 'Slovakia', 'Hungary', 'Ireland', 'Northern Ireland', 'Scotland',
    'Wales', 'Russia', 'Ukraine', 'Serbia', 'Slovenia', 'Bosnia Herzegovina', 'Greece', 'Turkey',
    'Romania', 'Bulgaria', 'Georgia', 'Albania', 'North Macedonia', 'Armenia', 'Montenegro',
    'Kosovo', 'Estonia', 'Latvia', 'Lithuania', 'Moldova', 'Luxembourg', 'Liechtenstein', 'San Marino', 'Malta', 'Andorra'
]

# %%
df['team_position'].unique()
# Out:
# array(['RW', 'LW', 'CAM', 'GK', 'RCM', 'LCB', 'ST', 'CDM', 'LDM', 'RM',
#        'RCB', 'LCM', 'LM', 'CF', 'SUB', 'LB', 'LS', 'RB', 'RDM', 'RES',
#        'RAM', 'RS', 'RF', 'CM', 'CB', 'LF', 'LAM', 'RWB', 'LWB'],
#       dtype=object)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='GK')&(df['potential']>88)]
players
# Out:
#         short_name  age  height_cm  weight_kg nationality               club  \
# 3         J. Oblak   26        188         87    Slovenia    Atlético Madrid
# 6    M. ter Stegen   27        187         85     Germany       FC Barcelona
# 14          De Gea   28        192         82       Spain  Manchester United
# 28     T. Courtois   27        199         96     Belgium        Real Madrid
# 74   G. Donnarumma   20        196         90       Italy              Milan
# 111           Kepa   24        186         85       Spain            Chelsea
# 753       A. Meret   22        190         83       Italy             Napoli
#
#      overall  potential  value_eur  wage_eur preferred_foot  \
# 3         91         93   77500000    125000          Right
# 6         90         93   67500000    250000          Right
# 14        89         90   56000000    205000          Right
# 28        88         89   48000000    235000           Left
# ...

# %%
players['value_eur'].mean()
# Out:
# np.float64(47928571.428571425)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='CB')&(df['potential']>80)]
players
# Out:
#          short_name  age  height_cm  weight_kg  nationality  \
# 126      S. de Vrij   27        189         78  Netherlands
# 231       F. Acerbi   31        192         88        Italy
# 377    L. Koscielny   33        186         75       France
# 474   J. Guilavogui   28        188         77       France
# 573       I. Konaté   20        192         93       France
# 800    J. Lascelles   25        188         89      England
# 2672       J. Gélin   22        183         79       France
#
#                           club  overall  potential  value_eur  wage_eur  \
# 126                      Inter       84         85   31500000     88000
# 231                      Lazio       83         83   19000000     64000
# 377   FC Girondins de Bordeaux       81         81    8500000     39000
# 474              VfL Wolfsburg       80         81   14500000     51000
# 573                 RB Leipzig       79         88   18000000     36000
# ...

# %%
players['value_eur'].mean()
# Out:
# np.float64(15642857.142857144)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='LB')&(df['potential']>85)]
players
# Out:
#        short_name  age  height_cm  weight_kg nationality               club  \
# 51     Jordi Alba   30        170         68       Spain       FC Barcelona
# 82   A. Robertson   25        178         64    Scotland          Liverpool
# 92       D. Alaba   27        180         78     Austria  FC Bayern München
# 174      Grimaldo   23        171         69       Spain         SL Benfica
# 179      L. Digne   25        178         74      France            Everton
# 339          Gayà   24        172         66       Spain        Valencia CF
#
#      overall  potential  value_eur  wage_eur preferred_foot  \
# 51        87         87   40000000    240000           Left
# 82        85         89   43500000    125000           Left
# 92        85         86   38000000    135000           Left
# 174       83         87   29500000     18000           Left
# 179       83         86   28500000     97000           Left
# 339       81         86   21000000     35000           Left
#
# ...

# %%
players['value_eur'].mean()
# Out:
# np.float64(33416666.666666668)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='RB')&(df['potential']>85)]
players
# Out:
#               short_name  age  height_cm  weight_kg nationality  \
# 61            J. Kimmich   24        176         73     Germany
# 94              Carvajal   27        173         73       Spain
# 160  T. Alexander-Arnold   20        180         69     England
# 249        Nélson Semedo   25        177         67    Portugal
# 571       A. Wan-Bissaka   21        183         72     England
# 582            T. Kehrer   22        186         76     Germany
# 994          D. Calabria   22        176         70       Italy
#
#                     club  overall  potential  value_eur  wage_eur  \
# 61     FC Bayern München       86         88   48000000    125000
# 94           Real Madrid       85         86   38000000    205000
# 160            Liverpool       83         89   32000000     78000
# 249         FC Barcelona       82         87   26000000    150000
# 571    Manchester United       79         88   17500000     71000
# ...

# %%
players['value_eur'].mean()
# Out:
# np.float64(27214285.714285713)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='CDM')&(df['potential']>85)]
players
# Out:
#            short_name  age  height_cm  weight_kg         nationality  \
# 21    Sergio Busquets   30        189         76               Spain
# 52             Thiago   28        174         70               Spain
# 65          M. Pjanić   29        178         72  Bosnia Herzegovina
# 755           D. Rice   20        185         80             England
# 1615        S. Tonali   19        181         79               Italy
#
#                    club  overall  potential  value_eur  wage_eur  \
# 21         FC Barcelona       89         89   55000000    300000
# 52    FC Bayern München       87         87   50000000    180000
# 65             Juventus       86         86   42500000    180000
# 755     West Ham United       78         87   15000000     49000
# 1615            Brescia       75         89   13500000      7000
#
#      preferred_foot  international_reputation  weak_foot  skill_moves  \
# 21            Right                         4          3            3
# ...

# %%
players['value_eur'].mean()
# Out:
# np.float64(35200000.0)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='CAM')&(df['potential']>85)]
players
# Out:
#           short_name  age  height_cm  weight_kg  nationality  \
# 37           M. Reus   30        180         71      Germany
# 113          D. Alli   23        188         80      England
# 247      S. Bergwijn   21        178         78  Netherlands
# 334   D. van de Beek   22        184         74  Netherlands
# 756       F. Neuhaus   22        183         74      Germany
# 2122      N. Zaniolo   19        190         79        Italy
#
#                           club  overall  potential  value_eur  wage_eur  \
# 37           Borussia Dortmund       88         88   56000000    170000
# 113          Tottenham Hotspur       84         89   41500000    115000
# 247                        PSV       82         87   30000000     22000
# 334                       Ajax       81         87   24500000     24000
# 756   Borussia Mönchengladbach       78         87   15500000     26000
# 2122                      Roma       74         88   12000000     18000
#
# ...

# %%
players['value_eur'].mean()
# Out:
# np.float64(29916666.666666668)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='LM')&(df['potential']>85)]
players
# Out:
#              short_name  age  height_cm  weight_kg  nationality  \
# 168      Gonçalo Guedes   22        179         68     Portugal
# 171         M. Rashford   21        186         70      England
# 176            T. Lemar   23        171         62       France
# 182         Y. Carrasco   25        180         71      Belgium
# 1622        J. Kluivert   20        171         66  Netherlands
# 2121      D. Szoboszlai   18        186         74      Hungary
# 3292  A. Claude Maurice   21        174         62       France
#
#                       club  overall  potential  value_eur  wage_eur  \
# 168            Valencia CF       83         88   34500000     46000
# 171      Manchester United       83         88   35500000    125000
# 176        Atlético Madrid       83         87   34000000     64000
# 182       Dalian YiFang FC       83         86   32500000     23000
# 1622                  Roma       75         86   11500000     29000
# ...

# %%
players['value_eur'].mean()
# Out:
# np.float64(23785714.285714287)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='RM')&(df['potential']>86)]
players
# Out:
#        short_name  age  height_cm  weight_kg nationality               club  \
# 27     C. Eriksen   27        181         76     Denmark  Tottenham Hotspur
# 108     J. Sancho   19        180         76     England  Borussia Dortmund
# 121      N. Fekir   25        173         75      France         Real Betis
# 418  Carlos Soler   22        180         76       Spain        Valencia CF
#
#      overall  potential  value_eur  wage_eur preferred_foot  \
# 27        88         89   68000000    205000          Right
# 108       84         92   44500000     61000          Right
# 121       84         87   39000000     40000           Left
# 418       80         87   21000000     36000          Right
#
#      international_reputation  weak_foot  skill_moves      work_rate  \
# 27                          3          5            4      High/High
# 108                         2          4            5     Medium/Low
# 121                         3          3            4    High/Medium
# ...

# %%
players['value_eur'].mean()
# Out:
# np.float64(43125000.0)

# %%
players = df[(df['nationality'].isin(european_countries))&(df['team_position']=='ST')&(df['potential']>86)]
players
# Out:
#          short_name  age  height_cm  weight_kg nationality               club  \
# 12          H. Kane   25        188         89     England  Tottenham Hotspur
# 20   R. Lewandowski   30        184         80      Poland  FC Bayern München
# 163      A. Martial   23        184         76      France  Manchester United
# 241      A. Belotti   25        181         72       Italy             Torino
#
#      overall  potential  value_eur  wage_eur preferred_foot  \
# 12        89         91   83000000    220000          Right
# 20        89         89   64500000    235000          Right
# 163       83         88   34500000    140000          Right
# 241       82         87   30000000     63000          Right
#
#      international_reputation  weak_foot  skill_moves    work_rate  \
# 12                          3          4            3    High/High
# 20                          4          4            4  High/Medium
# 163                         3          3            4   Medium/Low
# ...

# %%
players['value_eur'].max()
# Out:
# 83000000

# %% [markdown]
# Important playing 11 positions are GK, 2 CBs, LB, RB, 2 CDMs, CAM, LM, RM, ST
# Ideal budget to create a competitive team:
# 1 Goal Keeper = 48M
# 2 Center Back = 30M
# 1 Left Back = 33M
# 1 Right Back = 27M
# 2 Center Defensive Midfielder = 70M
# 1 Center Attacking Midfielder = 30M
# 1 Left Midfielder = 24M
# 1 Right Midfielder = 43M
# 1 Striker = 53M
#
# Therefore, the buget to buy players to form a team is about 360M Euros approx.
# Then have to pay wages of minimum 100k euros for each Players.

# %% [markdown]
# Sample analysis of top n% players (e.g. top 5% of the player) to see if some important attributes such as Agility or BallControl or Strength have been popular or not across the FIFA versions. An example would be seeing that the top 5% players of FIFA 20 are faster (higher Acceleration and Agility) compared to FIFA 15. The trend of attributes is also an important indication of how some attributes are necessary for players to win games (a version with more top 5% players with high BallControl stats would indicate that the game is more focused on the technique rather than the physical aspect).

# %% [markdown]
# For the above query there is problem that the Dataset(FIFA 15) have not provived to us, So we can't able to complete the required analysis, instead we have done the above sample analysis with the dataset(FIFA20) with top 3% players.

# %%
# Top 3% of Players Analysis
top_n_players = df[(df['overall']>=80) & (df['potential']>=80)]
top_n_players
# Out:
#             short_name  age  height_cm  weight_kg nationality  \
# 0             L. Messi   32        170         72   Argentina
# 1    Cristiano Ronaldo   34        187         83    Portugal
# 2            Neymar Jr   27        175         68      Brazil
# 3             J. Oblak   26        188         87    Slovenia
# 4            E. Hazard   28        175         74     Belgium
# ..                 ...  ...        ...        ...         ...
# 563     Everton Andrão   35        177         75      Brazil
# 564     Welington Dano   31        178         69      Brazil
# 565       J. Serendero   31        190         85     Uruguay
# 566         M. Baldona   35        177         75     Uruguay
# 567           M. Nérez   31        178         69     Uruguay
#
#                     club  overall  potential  value_eur  wage_eur  \
# 0           FC Barcelona       94         94   95500000    565000
# 1               Juventus       93         93   58500000    405000
# ...

# %%
# Players sold value comparison
sns.histplot(data=top_n_players,x=top_n_players['value_eur'],kde=True)
# Out:
# <Axes: xlabel='value_eur', ylabel='Count'>

# %%
#Shooting Skills based on Player Position
plt.figure(figsize=(10,5))
sns.violinplot(data=top_n_players,x='team_position',y='shooting',inner='point')
plt.tight_layout()

# %%
#Defending Skills based on Player Position
plt.figure(figsize=(10,5))
sns.violinplot(data=top_n_players,x='team_position',y='defending')
plt.tight_layout()

# %%
# Correlation of Players Attributes
sns.heatmap(top_n_players[['overall','potential','pace','shooting','passing','dribbling','defending','physic']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Task-2

# %% [markdown]
# Explore football skills and cluster football players based on their attributes.

# %%
df_cpy = top_n_players.copy()

# %%
cols = ['age','height_cm','weight_kg','preferred_foot','work_rate','team_position','club','nationality',
        'potential','international_reputation','release_clause_eur','gk_diving', 'gk_handling', 'gk_kicking',
       'gk_reflexes', 'gk_speed', 'gk_positioning', 'attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking', 'defending_standing_tackle',
       'defending_sliding_tackle', 'goalkeeping_diving',
       'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'goalkeeping_reflexes', 'ls', 'st', 'rs',
       'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm',
       'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb',
       'rcb', 'rb']
df_cpy.drop(cols,inplace=True,axis=1)

# %%
df_cpy.shape
# Out:
# (568, 12)

# %%
# numerical columns
df_cpy.describe().columns
# Out:
# Index(['overall', 'value_eur', 'wage_eur', 'weak_foot', 'skill_moves', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic'],
#       dtype='object')

# %%
df_cpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 568 entries, 0 to 567
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   short_name   568 non-null    object
#  1   overall      568 non-null    int64
#  2   value_eur    568 non-null    int64
#  3   wage_eur     568 non-null    int64
#  4   weak_foot    568 non-null    int64
#  5   skill_moves  568 non-null    int64
#  6   pace         568 non-null    float64
#  7   shooting     568 non-null    float64
#  8   passing      568 non-null    float64
#  9   dribbling    568 non-null    float64
#  10  defending    568 non-null    float64
#  11  physic       568 non-null    float64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 57.7+ KB

# %%
names = df_cpy['short_name'].to_list()

# %%
df_cpy.drop(columns='short_name',axis=1,inplace=True)

# %%
df_cpy.shape
# Out:
# (568, 11)

# %%
"""
from sklearn.preprocessing import StandardScaler
x = df_cpy.values
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_norm = pd.DataFrame(x_scaled)
"""
# Out:
# '\nfrom sklearn.preprocessing import StandardScaler\nx = df_cpy.values\nscaler = StandardScaler()\nx_scaled = scaler.fit_transform(x)\nx_norm = pd.DataFrame(x_scaled)\n'

# %%
# Normalize
from sklearn import preprocessing
x = df_cpy.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_norm = pd.DataFrame(x_scaled)

# %%
x_norm.head()
# Out:
#          0         1         2     3     4         5         6     7   \
# 0  1.000000  0.905213  1.000000  0.75  0.75  0.857143  0.985294  1.00
# 1  0.928571  0.554502  0.716814  0.75  1.00  0.904762  1.000000  0.80
# 2  0.857143  1.000000  0.513274  1.00  1.00  0.920635  0.882353  0.90
# 3  0.785714  0.734597  0.221239  0.50  0.00  0.539683  0.514706  0.38
# 4  0.785714  0.853081  0.831858  0.75  0.75  0.920635  0.852941  0.88
#
#          8         9         10
# 0  1.000000  0.227273  0.478261
# 1  0.847826  0.166667  0.739130
# 2  0.978261  0.121212  0.304348
# 3  0.326087  0.590909  0.500000
# 4  0.956522  0.166667  0.478261

# %%
reduced = x_norm.copy()

# %%
# PCA
from sklearn.decomposition import PCA
pca = PCA(n_components = 3)
reduced = pd.DataFrame(pca.fit_transform(x_norm))

# %%
reduced.head()
# Out:
#           0         1         2
# 0  1.037815  0.942360 -0.722556
# 1  0.984539  0.657734 -0.466508
# 2  1.197510  0.647471 -0.565188
# 3 -0.370694  0.414744 -0.779836
# 4  0.941686  0.686784 -0.640926

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
cs = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,random_state=42)
    kmeans.fit(reduced)
    cs.append(kmeans.inertia_)
print("cs:",cs)
plt.plot(range(1,11),cs);
# Out:
# cs: [184.64940792773623, 96.94861477754537, 69.72394399334458, 61.12356565563875, 53.54128713951808, 38.55898275488078, 34.43155800258725, 30.448485057227508, 27.666998659779967, 23.897013294658052]

# %%
from sklearn.metrics import silhouette_score
sil = []
kmax = 10

# Calculate silhouette scores for k = 2 to kmax
for k in range(2, kmax + 1):
    kmeans = KMeans(n_clusters=k, random_state=15, n_init='auto').fit(reduced)
    labels = kmeans.labels_
    score = silhouette_score(reduced, labels, metric='euclidean')
    sil.append(score)

# Plot silhouette scores
plt.figure(figsize=(8, 5))
plt.plot(range(2, kmax + 1), sil, marker='o', linestyle='-', color='blue')
plt.title('Silhouette Score for Optimal K')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()

# %%
# K-means Cluster
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2)

# %%
kmeans = kmeans.fit(reduced)

# %%
labels = kmeans.predict(reduced)

# %%
centroid = kmeans.cluster_centers_
centroid
# Out:
# array([[-0.44353199,  0.0238126 , -0.02274887],
#        [ 0.34620522, -0.01858727,  0.01775695]])

# %%
clusters = labels.tolist()

# %%
reduced['clusters'] = clusters
reduced['names'] = names
reduced.columns = ['X','Y','Z','clusters','names']

# %%
reduced.head(7)
# Out:
#           X         Y         Z  clusters              names
# 0  1.037815  0.942360 -0.722556         1           L. Messi
# 1  0.984539  0.657734 -0.466508         1  Cristiano Ronaldo
# 2  1.197510  0.647471 -0.565188         1          Neymar Jr
# 3 -0.370694  0.414744 -0.779836         0           J. Oblak
# 4  0.941686  0.686784 -0.640926         1          E. Hazard
# 5  0.689766  0.933587 -0.285145         1       K. De Bruyne
# 6 -0.322678  0.439918 -0.737186         0      M. ter Stegen

# %%
sns.set(style='white', context='talk')
plt.figure(figsize=(10, 8))

sns.scatterplot(data=reduced, x='X', y='Y', hue='clusters', palette='Set2',
                s=70, alpha=0.7, edgecolor='black')

plt.title('Improved Cluster Visualization', fontsize=16)
plt.xlabel('Feature X')
plt.ylabel('Feature Y')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
# Plotting
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Create color palette
palette = sns.color_palette("hsv", len(reduced['clusters'].unique()))
colors = [palette[i] for i in reduced['clusters']]

# Scatter plot
ax.scatter(reduced['X'], reduced['Y'], reduced['Z'], c=colors, s=50, alpha=0.6)

# Labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Cluster Plot')

plt.show()

# %%
reduced['clusters'].value_counts()
# Out:
# clusters
# 1    318
# 0    250
# Name: count, dtype: int64

# %%
s_score = reduced.iloc[:,:3]
s_score
# Out:
#             X         Y         Z
# 0    1.037815  0.942360 -0.722556
# 1    0.984539  0.657734 -0.466508
# 2    1.197510  0.647471 -0.565188
# 3   -0.370694  0.414744 -0.779836
# 4    0.941686  0.686784 -0.640926
# ..        ...       ...       ...
# 563 -0.299218 -0.059650  0.233328
# 564  0.038502 -0.021597  0.413356
# 565 -0.593188 -0.414134 -0.175627
# 566 -0.172143 -0.074134  0.372195
# 567  0.008487 -0.068335  0.471659
#
# [568 rows x 3 columns]

# %%
from sklearn.metrics import silhouette_score
score=silhouette_score(s_score,labels)
score
# Out:
# np.float64(0.4136248110461289)

# %% [markdown]
# # Model Building

# %%
X = reduced.drop(columns=['clusters','names'],axis=1)
y = reduced['clusters']

# %%
X.columns
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
X.shape
# Out:
# (568, 3)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=15)

# %%
x_train.shape,x_test.shape
# Out:
# ((454, 3), (114, 3))

# %% [markdown]
# ## Implementing ML Algorithms

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000, solver='lbfgs'),
    'K-Nearest Neighbors': KNeighborsClassifier(  algorithm='ball_tree', leaf_size=5, n_jobs=2, n_neighbors=7, weights='distance'),
    'Decision Tree': DecisionTreeClassifier(criterion='gini', max_depth=10, max_leaf_nodes=7, min_samples_split=2, splitter='best'),
    'Random Forest': RandomForestClassifier(criterion='gini', min_samples_leaf=1, min_samples_split=2 ),
     'Gradient Boost': GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3),
    'Support Vector Machine': SVC(kernel='rbf', C=1.0, gamma='scale', probability=True)
}

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    print(f"\n{name}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Logistic Regression
# Accuracy: 1.0
# Confusion Matrix:
#  [[46  0]
#  [ 0 68]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        46
#            1       1.00      1.00      1.00        68
#
#     accuracy                           1.00       114
#    macro avg       1.00      1.00      1.00       114
# weighted avg       1.00      1.00      1.00       114
#
#
# K-Nearest Neighbors
# Accuracy: 0.9736842105263158
# Confusion Matrix:
#  [[44  2]
#  [ 1 67]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        46
#            1       0.97      0.99      0.98        68
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
#
# Decision Tree
# Accuracy: 1.0
# Confusion Matrix:
#  [[46  0]
#  [ 0 68]]
# ...

# %%
lr = LogisticRegression(max_iter=1000, solver='lbfgs')
knn =  KNeighborsClassifier(algorithm='ball_tree', leaf_size=5, n_jobs=2, n_neighbors=7, weights='distance')
dtc = DecisionTreeClassifier(criterion='gini', max_depth=10, max_leaf_nodes=7, min_samples_split=2, splitter='best')
rfc = RandomForestClassifier(criterion='gini', min_samples_leaf=1, min_samples_split=2)
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3)
svc = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True)

# %% [markdown]
# ## Model Prediction

# %%
x_test.iloc[5:10]
# Out:
#             X         Y         Z
# 533 -0.181324  0.014662  0.329084
# 409  0.105334 -0.501988 -0.178488
# 421  0.067905 -0.450444 -0.230193
# 44  -0.023770  0.477038  0.092644
# 556  0.567939 -0.430402 -0.062569

# %%
y_test.iloc[5:10]
# Out:
# 533    0
# 409    1
# 421    1
# 44     1
# 556    1
# Name: clusters, dtype: int64

# %%
new_predictions=[0.067905 	,-0.450444 	,-0.230193]

# %%
#Logistic Regression
lr.fit(x_train,y_train)
new_lr=lr.predict([new_predictions])
if new_lr[0]==1:
    print('Good Player with average Potential and Overall Ratings')
else:
    print('Best Player with outstanding Potential and Overall Ratings')
# Out:
# Good Player with average Potential and Overall Ratings

# %%
#KNN
knn.fit(x_train,y_train)
new_knn=knn.predict([new_predictions])
if new_knn[0]==1:
    print('Good Player with average Potential and Overall Ratings')
else:
    print('Best Player with outstanding Potential and Overall Ratings')
# Out:
# Good Player with average Potential and Overall Ratings

# %%
#Decision Tree Classifier
dtc.fit(x_train,y_train)
new_dtc=dtc.predict([new_predictions])
if new_dtc[0]==1:
    print('Good Player with average Potential and Overall Ratings')
else:
    print('Best Player with outstanding Potential and Overall Ratings')
# Out:
# Good Player with average Potential and Overall Ratings

# %%
#Random Forest Classifier
rfc.fit(x_train,y_train)
new_rfc=rfc.predict([new_predictions])
if new_rfc[0]==1:
    print('Good Player with average Potential and Overall Ratings')
else:
    print('Best Player with outstanding Potential and Overall Ratings')
# Out:
# Good Player with average Potential and Overall Ratings

# %%
#GradientBoostingClassifier
gbc.fit(x_train,y_train)
new_gbc=gbc.predict([new_predictions])
if new_gbc[0]==1:
    print('Good Player with average Potential and Overall Ratings')
else:
    print('Best Player with outstanding Potential and Overall Ratings')
# Out:
# Good Player with average Potential and Overall Ratings

# %%
#Support Vector Classifier
svc.fit(x_train,y_train)
new_svc=svc.predict([new_predictions])
if new_svc[0]==1:
    print('Good Player with average Potential and Overall Ratings')
else:
    print('Best Player with outstanding Potential and Overall Ratings')
# Out:
# Good Player with average Potential and Overall Ratings

# %% [markdown]
# ## Model Comparision Report

# %% [markdown]
# Different Models such as Logistic Regression, K-Nearest Neighbors, Decision Tree, Random Forest and SVM are applied. The Evaluation Metrics for the mentioned models are nearer 99% accuracy and only KNN metrics is less than other models.
#
# Almost all the above models with unseen data results the same predictions. Therefore we conclude our reports as optional based on requirements:
#
# *   If interpretability and speed are important we can use Logistic Regression.
# *   If slightly better generalization and robustness are desired (especially on larger, more complex datasets) we can use Random Forest

# %% [markdown]
# ## Report on Challenges Faced

# %% [markdown]
# There are large number of features present in dataset which have not been mentioned in the Attributes of Project document.
#
# Analysis such as "An example would be seeing that the top 5% players of FIFA 20 are faster (higher Acceleration and Agility) compared to FIFA 15".
# Here only FIFA20 dataset was provided and not FIFA15.
#
# Apart from that all the other tasks and the analysis were done.

# %% [markdown]
#  Batch : 16-DEC-24-CDS-BUN-021-WDM0900-CBE
